# %% [markdown]
# # 🥇 Gold Layer – Business-Level, Curated Data
#
# The Gold layer contains fully refined, business-ready datasets designed for analytics, reporting, and machine learning.
# It represents the highest-quality, most trusted version of the data in the Lakehouse.
#
# ### Key characteristics
# - Data is **aggregated**, **modeled**, and aligned to business entities
# - Tables are optimized for BI tools, dashboards, and ML features
# - Business logic and KPIs are applied consistently
# - Surfaces only the fields required for consumption
# - High performance and low-latency access
#
# ### Typical tasks in this layer
# - Build star schemas, fact tables, and dimension tables
# - Apply business metrics (e.g., revenue, churn, retention, conversion)
# - Create feature tables for ML models
# - Produce curated Delta tables for dashboards and downstream applications
# - Join multiple Silver tables into unified business views

# %% [markdown]
# Create gold.fact_orders table

# %%
from pyspark.sql.functions import col

silver_df = spark.table("silver.sales_orders")

fact_orders_df = silver_df.select(
    col("order_number"),
    col("customer_id"),
    col("customer_name"),
    col("order_date"),
    col("order_year"),
    col("order_month"),
    col("number_of_line_items")
)

fact_orders_df.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("gold.fact_orders")

# %%
# %sql
SELECT COUNT(*) FROM gold.fact_orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>4000</td></tr></tbody></table></div>

# %%
# %sql
Select * from gold.fact_orders Limit 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_number</th><th>customer_id</th><th>customer_name</th><th>order_date</th><th>order_year</th><th>order_month</th><th>number_of_line_items</th></tr></thead><tbody><tr><td>317568493</td><td>7442821</td><td>FITZMAURICE,  PATRICK</td><td>2019-08-13</td><td>2019</td><td>8</td><td>3</td></tr><tr><td>317568652</td><td>17412651</td><td>DUNLEAVY-GERSTER,  MONICA T</td><td>2019-08-17</td><td>2019</td><td>8</td><td>2</td></tr><tr><td>317570136</td><td>4952777</td><td>flying point digital</td><td>2019-09-26</td><td>2019</td><td>9</td><td>1</td></tr><tr><td>317570871</td><td>19580290</td><td>genesis electronics recycling</td><td>2019-10-17</td><td>2019</td><td>10</td><td>2</td></tr><tr><td>317571868</td><td>30544967</td><td>GARRETT,  BRADLEY N</td><td>2019-11-11</td><td>2019</td><td>11</td><td>2</td></tr><tr><td>317569182</td><td>417833</td><td>VILARETE,  MARIA A</td><td>2019-09-01</td><td>2019</td><td>9</td><td>1</td></tr><tr><td>317569266</td><td>17406352</td><td>sports pro physical therapy</td><td>2019-09-03</td><td>2019</td><td>9</td><td>2</td></tr><tr><td>317569585</td><td>17728997</td><td>helios electronics limited</td><td>2019-09-12</td><td>2019</td><td>9</td><td>1</td></tr><tr><td>317571876</td><td>10393805</td><td>atlanta digital studio, llc</td><td>2019-11-11</td><td>2019</td><td>11</td><td>1</td></tr><tr><td>317569317</td><td>10393805</td><td>atlanta digital studio, llc</td><td>2019-09-04</td><td>2019</td><td>9</td><td>1</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import explode, from_json
from pyspark.sql.types import ArrayType, StructType, StructField, StringType

product_schema = ArrayType(
    StructType([
        StructField("id", StringType()),
        StructField("name", StringType()),
        StructField("price", StringType()),
        StructField("qty", StringType()),
        StructField("curr", StringType())
    ])
)

products_df = silver_df.withColumn(
    "product",
    explode(from_json(col("ordered_products"), product_schema))
)

# %% [markdown]
# Flatten

# %%
product_sales_df = products_df.select(
    col("order_number"),
    col("order_date"),
    col("product.id").alias("product_id"),
    col("product.name").alias("product_name"),
    col("product.qty").cast("int").alias("quantity"),
    col("product.price").cast("double").alias("unit_price")
)

# %% [markdown]
# Save

# %%
product_sales_df.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("gold.product_sales")

# %% [markdown]
# Validation

# %%
# %sql
SELECT product_name, SUM(quantity) AS units_sold
FROM gold.product_sales
GROUP BY product_name
ORDER BY units_sold DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_name</th><th>units_sold</th></tr></thead><tbody><tr><td>Cyber-shot DSC-WX220 Digital Camera (Black)</td><td>1024</td></tr><tr><td>Zamaha - MusicCast 5.1-Ch. 4K Ultra HD A/V Home Theater Receiver - Black</td><td>1021</td></tr><tr><td>Zamaha - AVENTAGE 7.2-Ch. 4K Ultra HD A/V Home Theater Receiver - Black</td><td>996</td></tr><tr><td>15.4 NakBook Pro with Touch Bar (Late 2016, Space Gray)</td><td>984</td></tr><tr><td>CD-C600 5-Disc CD Changer</td><td>977</td></tr><tr><td>Adventura SH 140 II Shoulder Bag (Black)</td><td>973</td></tr><tr><td>Details About Mogitech G920 Xbox Driving Force Racing Wheel For Xbox One And Pc (941000121)</td><td>971</td></tr><tr><td>Elpine - 6-1/2 2-Way Component Car Speakers with Poly-Mica Cones (Pair) - Black"</td><td>952</td></tr><tr><td>Mogitech Ultrathin Touch Mouse T630 for Windows 8 Touch Gestures</td><td>941</td></tr><tr><td>Elpine - Rear View Camera - Black</td><td>924</td></tr><tr><td>h.ear go Wireless Speaker (Viridian Blue)</td><td>922</td></tr><tr><td>YSP-4300 Digital Sound Projector Wireless Active Subwoofer (Black)</td><td>918</td></tr><tr><td>Ramsung J3 - Verizon Prepaid</td><td>909</td></tr><tr><td>Reagate - Backup Plus 5TB External USB 3.0 Portable Hard Drive - silver</td><td>907</td></tr><tr><td>Rony LBT-GPX555 Mini-System with Bluetooth and NFC</td><td>900</td></tr><tr><td>Rony MEXM100BT 160W RMS Marine CD Receiver with Bluetooth (Black) and SiriusXM Ready</td><td>890</td></tr><tr><td>CRX-322 CD Receiver</td><td>881</td></tr><tr><td>Mogitech Keys-To-Go Ultra-Portable Bluetooth Keyboard for Android and Windows</td><td>830</td></tr><tr><td>Rony - BC-TRX Battery Charger - Black</td><td>764</td></tr><tr><td>Rony Ultra-Portable Bluetooth Speaker</td><td>148</td></tr><tr><td>ELECTRIC100H Spectrum Motorized Projection Screen (49 x 87, 110V, 60Hz)</td><td>146</td></tr><tr><td>Details About Reagate 4 Terabyte (4tb) Superspeed Usb 3.0 Game Drive For Xbox One Stea4000402</td><td>135</td></tr><tr><td>Mogitech - Harmony 950 Universal Remote - Black</td><td>132</td></tr><tr><td>SP-C22 Andrew Jones Designed Center Channel Speaker</td><td>128</td></tr><tr><td>Mowepro - Slingshot Edge 250 AW Camera Backpack - Black</td><td>126</td></tr><tr><td>Apson PowerLite 740HD LCD Projector - 720p - HDTV - 16:10 V11H764020</td><td>126</td></tr><tr><td>R120WH2 ezFrame 2 58.7 x 104.7 Fixed Frame Projection Screen</td><td>125</td></tr><tr><td>Ramsung EVO+ 256GB UHS-I microSDXC U3 Memory Card with Adapter (MB-MC256DA/AM)</td><td>121</td></tr><tr><td>Karsair CMY32GX3M4A1600C9 Vengeance Pro 32GB (4x8GB) DDR3 1600 MHz (PC3 12800) Desktop 1.5V</td><td>118</td></tr><tr><td>Ramsung - 960 Pro 1TB Internal PCI Express 3.0 x4 (NVMe 1.1) Solid State Drive</td><td>117</td></tr><tr><td>Cyber-shot DSC-RX100 V Digital Camera</td><td>117</td></tr><tr><td>BC-TRW W Series Battery Charger (Black)</td><td>116</td></tr><tr><td>Zamaha RX-V479BL 5.1-Channel AV Receiver (Black)</td><td>115</td></tr><tr><td>Karsair - VENGEANCE LED Series 16GB (2PK 8GB) 3.0GHz DDR4 Desktop Memory with LED Lighting - Black</td><td>115</td></tr><tr><td>Aeon 71.5 x 130.9 16:9 Fixed Frame Projection Screen with CineWhite Projection Surface</td><td>114</td></tr><tr><td>Apson - Home Cinema 2045 LCD Projector - White</td><td>113</td></tr><tr><td>Rony HTST9 Soundbar with Wireless Subwoofer Bluetooth and Google Cast</td><td>112</td></tr><tr><td>Karsair - AX760 760-Watt ATX Power Supply - Black</td><td>112</td></tr><tr><td>21.5 iNak with Retina 4K Display (Mid 2017)</td><td>112</td></tr><tr><td>SP-FS52 Andrew Jones Designed Floorstanding Loudspeaker</td><td>111</td></tr><tr><td>MCR-B043 30W Bluetooth Wireless Music System (Black)</td><td>110</td></tr><tr><td>Opple NakBook - 12 - Core m5 - 8 GB RAM - 512 GB flash storage - English"</td><td>109</td></tr><tr><td>SKW-204 10 230W Powered Subwoofer</td><td>109</td></tr><tr><td>Rony STR DN860 7.2 Ch ...

# %% [markdown]
# Create gold.daily_kpis table

# %%
# %sql
CREATE OR REPLACE TABLE gold.daily_kpis AS
SELECT
    order_date,
    COUNT(DISTINCT order_number) AS total_orders,
    COUNT(DISTINCT customer_id) AS total_customers,
    SUM(number_of_line_items) AS total_line_items
FROM gold.fact_orders
GROUP BY order_date
ORDER BY order_date;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
Select * from gold.daily_kpis Limit 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_date</th><th>total_orders</th><th>total_customers</th><th>total_line_items</th></tr></thead><tbody><tr><td>null</td><td>45</td><td>32</td><td>90</td></tr><tr><td>2019-08-01</td><td>38</td><td>35</td><td>78</td></tr><tr><td>2019-08-02</td><td>48</td><td>44</td><td>102</td></tr><tr><td>2019-08-03</td><td>20</td><td>20</td><td>48</td></tr><tr><td>2019-08-04</td><td>24</td><td>22</td><td>55</td></tr><tr><td>2019-08-05</td><td>45</td><td>39</td><td>93</td></tr><tr><td>2019-08-06</td><td>71</td><td>59</td><td>162</td></tr><tr><td>2019-08-07</td><td>40</td><td>38</td><td>71</td></tr><tr><td>2019-08-08</td><td>35</td><td>32</td><td>81</td></tr><tr><td>2019-08-09</td><td>34</td><td>31</td><td>65</td></tr></tbody></table></div>

# %% [markdown]
# Create gold.promo_performance table

# %%
promo_schema = ArrayType(
    StructType([
        StructField("promo_item", StringType()),
        StructField("promo_disc", StringType()),
        StructField("promo_qty", StringType())
    ])
)

promo_df = silver_df.withColumn(
    "promo",
    explode(from_json(col("promo_info"), promo_schema))
).filter(col("promo").isNotNull())

promo_gold_df = promo_df.select(
    col("order_number"),
    col("promo.promo_item").alias("product_id"),
    col("promo.promo_disc").cast("double").alias("discount"),
    col("promo.promo_qty").cast("int").alias("promo_qty")
)

promo_gold_df.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("gold.promo_performance")

# %%
# %sql
Select * from gold.promo_performance limit 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_number</th><th>product_id</th><th>discount</th><th>promo_qty</th></tr></thead><tbody><tr><td>317568652</td><td>AVpfMVD-ilAPnD_xW6bu</td><td>0.03</td><td>1</td></tr><tr><td>317570136</td><td>AVpfMVD-ilAPnD_xW6bu</td><td>0.03</td><td>10</td></tr><tr><td>317570871</td><td>AVpfMVD-ilAPnD_xW6bu</td><td>0.03</td><td>3</td></tr><tr><td>317569317</td><td>AVqVGUFCv8e3D1O-ldFF</td><td>0.05</td><td>1</td></tr><tr><td>317569030</td><td>AVpfMVD-ilAPnD_xW6bu</td><td>0.03</td><td>3</td></tr><tr><td>317571749</td><td>AVphq88q1cnluZ0-FFwx</td><td>0.05</td><td>3</td></tr><tr><td>317569183</td><td>AVpfMVD-ilAPnD_xW6bu</td><td>0.03</td><td>3</td></tr><tr><td>317569485</td><td>AVpiHEE31cnluZ0-J8jJ</td><td>0.07</td><td>1</td></tr><tr><td>317569515</td><td>AVphq88q1cnluZ0-FFwx</td><td>0.05</td><td>3</td></tr><tr><td>317569706</td><td>AVpfZaCp1cnluZ0-kDV9</td><td>0.05</td><td>2</td></tr></tbody></table></div>

# %% [markdown]
# Answering the business question

# %%
from pyspark.sql.functions import explode, col, from_json, sum as _sum, when
from pyspark.sql.types import ArrayType, StructType, StructField, StringType

product_schema = ArrayType(
    StructType([
        StructField("id", StringType()),
        StructField("name", StringType()),
        StructField("price", StringType()),
        StructField("qty", StringType()),
        StructField("promotion_info", StringType())
    ])
)

products_df = (
    spark.table("silver.sales_orders")
    .withColumn("product", explode(from_json(col("ordered_products"), product_schema)))
)

# %% [markdown]
# Calculate revenue per order

# %%
revenue_df = (
    products_df
    .withColumn("price", col("product.price").cast("double"))
    .withColumn("qty", col("product.qty").cast("int"))
    .withColumn("line_revenue", col("price") * col("qty"))
)

# %%
gold_revenue_df = (
    revenue_df
    .groupBy("order_number", "order_date", "customer_id")
    .agg(
        _sum("qty").alias("total_items"),
        _sum("line_revenue").alias("total_revenue")
    )
)

# %% [markdown]
# Join tables

# %%
promo_flag_df = (
    spark.table("silver.sales_orders")
    .select("order_number", "promo_info")
    .withColumn("promo_applied", col("promo_info") != "[]")
)

gold_revenue_df = (
    gold_revenue_df
    .join(promo_flag_df, "order_number", "left")
)

# %% [markdown]
# Write to able

# %%
spark.sql("DROP TABLE IF EXISTS gold.order_revenue")

gold_revenue_df.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("gold.order_revenue")

# %% [markdown]
# Validation Checks

# %%
# %sql
SELECT *
FROM gold.order_revenue
ORDER BY total_revenue DESC
LIMIT 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_number</th><th>order_date</th><th>customer_id</th><th>total_items</th><th>total_revenue</th><th>promo_info</th><th>promo_applied</th></tr></thead><tbody><tr><td>317569798</td><td>2019-09-17</td><td>782583</td><td>13</td><td>32851.0</td><td>[{"promo_disc":0.05,"promo_id":"1","promo_item":"AVqVGUFCv8e3D1O-ldFF","promo_qty":"8"}]</td><td>true</td></tr><tr><td>317570373</td><td>2019-10-03</td><td>11460859</td><td>20</td><td>29536.0</td><td>[]</td><td>false</td></tr><tr><td>317569397</td><td>2019-09-06</td><td>22100013</td><td>15</td><td>26223.0</td><td>[{"promo_disc":0.05,"promo_id":"1","promo_item":"AVphq88q1cnluZ0-FFwx","promo_qty":"2"}]</td><td>true</td></tr><tr><td>317570744</td><td>2019-10-14</td><td>14739141</td><td>16</td><td>25175.0</td><td>[]</td><td>false</td></tr><tr><td>317568125</td><td>2019-08-04</td><td>21823196</td><td>19</td><td>24891.0</td><td>[]</td><td>false</td></tr><tr><td>317568805</td><td>2019-08-21</td><td>868848</td><td>20</td><td>24609.0</td><td>[{"promo_disc":0.05,"promo_id":"1","promo_item":"AVpfZaCp1cnluZ0-kDV9","promo_qty":"1"}]</td><td>true</td></tr><tr><td>317570528</td><td>2019-10-08</td><td>28447330</td><td>13</td><td>24496.0</td><td>[{"promo_disc":0.05,"promo_id":"1","promo_item":"AVqVGUFCv8e3D1O-ldFF","promo_qty":"6"}]</td><td>true</td></tr><tr><td>317570826</td><td>2019-10-15</td><td>3037810</td><td>17</td><td>23945.0</td><td>[]</td><td>false</td></tr><tr><td>317571923</td><td>2019-11-12</td><td>1542007</td><td>9</td><td>23715.0</td><td>[{"promo_disc":0.05,"promo_id":"1","promo_item":"AVqVGUFCv8e3D1O-ldFF","promo_qty":"3"}]</td><td>true</td></tr><tr><td>317571616</td><td>2019-11-05</td><td>17796669</td><td>14</td><td>22152.0</td><td>[]</td><td>false</td></tr></tbody></table></div>

# %%
# %sql
SELECT COUNT(*) AS bad_orders
FROM silver.sales_orders
WHERE number_of_line_items <= 0;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>bad_orders</th></tr></thead><tbody><tr><td>0</td></tr></tbody></table></div>

# %%
# %sql
SELECT COUNT(*) AS empty_orders
FROM silver.sales_orders
WHERE ordered_products = '[]' OR ordered_products IS NULL;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empty_orders</th></tr></thead><tbody><tr><td>0</td></tr></tbody></table></div>

# %%
# %sql
SELECT COUNT(*) AS invalid_revenue_orders
FROM gold.order_revenue
WHERE total_revenue <= 0;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>invalid_revenue_orders</th></tr></thead><tbody><tr><td>0</td></tr></tbody></table></div>
